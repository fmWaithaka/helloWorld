# %% [markdown]
# # Linear search

# %%
import math

# %%
def locate_card(cards, query):
    pass

# %%
# test cases
cards = [13, 11, 10, 7, 4 , 3, 1, 0]
query = 7
output = 3

# %%
result = locate_card(cards, query)
print(result)
# Out:
# None

# %%
result == output
# Out:
# False

# %%
# Test case
test = {
    'input': {
        'cards': [13, 11, 10, 7, 4 , 3, 1, 0],
        'query': 7
    },
    'output': 3
}

# %%
# locate_card(test['input']['cards'], test['input']['query']) == test['output']

# instead of the above code you can use this code
locate_card(**test['input']) == test['output']
# Out:
# False

# %%
tests = []

# %%
# query in the middle
tests.append(test)

tests.append({
    'input': {
        'cards': [13, 11, 10, 7, 4 , 3, 1, 0],
        'query': 1
    },
    'output': 6
})

# %%
# query is the last element

tests.append({
    'input': {
        'cards': [3, -1, -9, -127],
        'query': -127
    },
    'output': 3
})

# %%
# query is the first element
tests.append({
    'input': {
        'cards': [3, -1, -9, -127],
        'query': 3
    },
    'output': 0
})

# %%
# cards contains just one number

tests.append({
    'input': {
        'cards': [6],
        'query': 6
    },
    'output': 0
})

# %%
# cards does not contain query
tests.append({
    'input': {
        'cards': [3, -1, -9, -127],
        'query': 4
    },
    'output': -1
})

# %%
# Card is empty
tests.append({
    'input': {
        'cards': [],
        'query': 3
    },
    'output': -1
})

# %%
# The number itself can repeat in cards
tests.append({
    'input': {
        'cards': [3, 3, 3 ,3, 2, -1, -1,-1, -1, -9, -127],
        'query': 2
    },
    'output': 4
})

# %%
# query occuss in multiple positions
tests.append({
    'input': {
        'cards': [7, 7, 7, 7, 3, 3, 3, 3, 3, 2, 2, 2, 1, 1],
        'query': 3
    },
    'output': 4
})

# %%
tests
# Out:
# [{'input': {'cards': [13, 11, 10, 7, 4, 3, 1, 0], 'query': 7}, 'output': 3},
#  {'input': {'cards': [13, 11, 10, 7, 4, 3, 1, 0], 'query': 1}, 'output': 6},
#  {'input': {'cards': [13, 11, 10, 7, 4, 3, 1, 0], 'query': 7}, 'output': 3},
#  {'input': {'cards': [3, -1, -9, -127], 'query': -127}, 'output': 3},
#  {'input': {'cards': [3, -1, -9, -127], 'query': 3}, 'output': 0},
#  {'input': {'cards': [6], 'query': 6}, 'output': 0},
#  {'input': {'cards': [3, -1, -9, -127], 'query': 4}, 'output': -1},
#  {'input': {'cards': [], 'query': 3}, 'output': -1},
#  {'input': {'cards': [3, 3, 3, 3, 2, -1, -1, -1, -1, -9, -127], 'query': 2},
#   'output': 4},
#  {'input': {'cards': [7, 7, 7, 7, 3, 3, 3, 3, 3, 2, 2, 2, 1, 1], 'query': 3},
#   'output': 4}]

# %%
def locate_card(cards, query):
    # create  a variable postion with the value 0
    position = 0
    
    # set up a loop for repetition
    while True:
        # check if the element at the current position matches the query
        if cards[position] == query:
            # answer found: Return and exit
            return position
        
        # Increment the position
        position += 1
        
        # check if we have reached to the end of the array
        if position == len(cards):
            
            # return -1 if the number not found
            return -1

# %%
test
# Out:
# {'input': {'cards': [13, 11, 10, 7, 4, 3, 1, 0], 'query': 7}, 'output': 3}

# %%
result = locate_card(**test['input'])
result
# Out:
# 3

# %%
result == output
# Out:
# True

# %%
 # !pip install jovian --upgrade --quiet

# %%
from jovian.pythondsa import evaluate_test_case

# %%
evaluate_test_case(locate_card, test)
# Out:
# Input:
# {'cards': [13, 11, 10, 7, 4, 3, 1, 0], 'query': 7}
#
# Expected Output:
# 3
#
#
# Actual Output:
# 3
#
# Execution Time:
# 0.008 ms
#
# Test Result:
# PASSED
# (3, True, 0.008)

# %%
from jovian.pythondsa import evaluate_test_cases

# %%
evaluate_test_cases(locate_card, tests)
# Out:
# TEST CASE #0
#
# Input:
# {'cards': [13, 11, 10, 7, 4, 3, 1, 0], 'query': 7}
#
# Expected Output:
# 3
#
#
# Actual Output:
# 3
#
# Execution Time:
# 0.016 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #1
#
# Input:
# {'cards': [13, 11, 10, 7, 4, 3, 1, 0], 'query': 1}
#
# Expected Output:
# 6
#
#
# Actual Output:
# 6
#
# Execution Time:
# 0.017 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #2
#
# Input:
# {'cards': [13, 11, 10, 7, 4, 3, 1, 0], 'query': 7}
#
# Expected Output:
# 3
#
#
# Actual Output:
# 3
#
# Execution Time:
# 0.014 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #3
#
# Input:
# {'cards': [3, -1, -9, -127], 'query': -127}
#
# Expected Output:
# 3
#
#
# Actual Output:
# 3
#
# Execution Time:
# 0.015 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #4
#
# Input:
# {'cards': [3, -1, -9, -127], 'query': 3}
#
# Expected Output:
# 0
#
#
# Actual Output:
# 0
#
# Execution Time:
# 0.009 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #5
#
# Input:
# {'cards': [6], 'query': 6}
#
# ...

# %%
def locate_card(cards, query):
    # create  a variable postion with the value 0
    position = 0
    
    print('cards:', cards)
    print('query:', query)
    
    # set up a loop for repetition
    while True:
        print('position:', position)
        # check if the element at the current position matches the query
        if cards[position] == query:
            # answer found: Return and exit
            return position
        
        # Increment the position
        position += 1
        
        # check if we have reached to the end of the array
        if position == len(cards):
            
            # return -1 if the number not found
            return -1

# %%
cards6 = tests[6]['input']['cards']
query6 = tests[6]['input']['query']

locate_card(cards6, query6)
# Out:
# cards: [3, -1, -9, -127]
# query: 4
# position: 0
# position: 1
# position: 2
# position: 3
# -1

# %%
cards7 = tests[7]['input']['cards']
query7 = tests[7]['input']['query']

locate_card(cards7, query7)
# Out:
# cards: []
# query: 3
# position: 0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[37], line 4
#       1 cards7 = tests[7]['input']['cards']
#       2 query7 = tests[7]['input']['query']
# ----> 4 locate_card(cards7, query7)
#
# Cell In[33], line 12, in locate_card(cards, query)
#      10 print('position:', position)
#      11 # check if the element at the current position matches the query
# ---> 12 if cards[position] == query:
#      13     # answer found: Return and exit
#      14     return position
#      16 # Increment the position
#
# IndexError: list index out of range

# %%
def locate_card(cards, query):
    position = 0
    while position < len(cards):
        if cards[position] == query:
            return position
        position += 1
    return -1

# %%
tests[7]
# Out:
# {'input': {'cards': [], 'query': 3}, 'output': -1}

# %%
locate_card(cards7, query7)
# Out:
# -1

# %%
evaluate_test_cases(locate_card, tests)
# Out:
# TEST CASE #0
#
# Input:
# {'cards': [13, 11, 10, 7, 4, 3, 1, 0], 'query': 7}
#
# Expected Output:
# 3
#
#
# Actual Output:
# 3
#
# Execution Time:
# 0.018 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #1
#
# Input:
# {'cards': [13, 11, 10, 7, 4, 3, 1, 0], 'query': 1}
#
# Expected Output:
# 6
#
#
# Actual Output:
# 6
#
# Execution Time:
# 0.015 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #2
#
# Input:
# {'cards': [13, 11, 10, 7, 4, 3, 1, 0], 'query': 7}
#
# Expected Output:
# 3
#
#
# Actual Output:
# 3
#
# Execution Time:
# 0.02 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #3
#
# Input:
# {'cards': [3, -1, -9, -127], 'query': -127}
#
# Expected Output:
# 3
#
#
# Actual Output:
# 3
#
# Execution Time:
# 0.015 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #4
#
# Input:
# {'cards': [3, -1, -9, -127], 'query': 3}
#
# Expected Output:
# 0
#
#
# Actual Output:
# 0
#
# Execution Time:
# 0.01 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #5
#
# Input:
# {'cards': [6], 'query': 6}
#
# ...

# %% [markdown]
# # Binary search

# %%
def locate_card(cards, query):
    low = 0
    high = len(cards)-1
    
    while low <= high:
        mid = (low + high) // 2
        mid_number = cards[mid]
        
        print("Low:", low, "High:", high, "mid:", mid, "mid_number:", mid_number)
          
        if mid_number == query:
            return mid
        elif mid_number < query:
            high = mid - 1
        elif mid_number > query:
            low = mid + 1
    return -1

# %%
evaluate_test_cases(locate_card, tests)
# Out:
# TEST CASE #0
# Low: 0 High: 7 mid: 3 mid_number: 7
#
# Input:
# {'cards': [13, 11, 10, 7, 4, 3, 1, 0], 'query': 7}
#
# Expected Output:
# 3
#
#
# Actual Output:
# 3
#
# Execution Time:
# 0.105 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #1
# Low: 0 High: 7 mid: 3 mid_number: 7
# Low: 4 High: 7 mid: 5 mid_number: 3
# Low: 6 High: 7 mid: 6 mid_number: 1
#
# Input:
# {'cards': [13, 11, 10, 7, 4, 3, 1, 0], 'query': 1}
#
# Expected Output:
# 6
#
#
# Actual Output:
# 6
#
# Execution Time:
# 0.224 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #2
# Low: 0 High: 7 mid: 3 mid_number: 7
#
# Input:
# {'cards': [13, 11, 10, 7, 4, 3, 1, 0], 'query': 7}
#
# Expected Output:
# 3
#
#
# Actual Output:
# 3
#
# Execution Time:
# 0.084 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #3
# Low: 0 High: 3 mid: 1 mid_number: -1
# Low: 2 High: 3 mid: 2 mid_number: -9
# Low: 3 High: 3 mid: 3 mid_number: -127
#
# Input:
# {'cards': [3, -1, -9, -127], 'query': -127}
#
# Expected Output:
# 3
#
#
# Actual Output:
# ...

# %%
evaluate_test_case(locate_card, tests[9])
# Out:
# Input:
# {'cards': [7, 7, 7, 7, 3, 3, 3, 3, 3, 2, 2, 2, 1, 1], 'query': 3}
#
# Expected Output:
# 4
#
# Low: 0 High: 13 mid: 6 mid_number: 3
#
# Actual Output:
# 6
#
# Execution Time:
# 0.13 ms
#
# Test Result:
# FAILED
# (6, False, 0.13)

# %%
# Helper function to cover the rare cases: repeating numbers
def test_location(cards, query, mid):
    mid_number = cards[mid]
    
    print('mid:', mid, ', mid_number:', mid_number)
    if mid_number == query:
        if mid-1 >= 0 and cards[mid-1] == query:
            return 'left'
        else:
            return 'found'
    elif mid_number < query:
        return 'left'
    else:
        return 'right'
    
def locate_card(cards, query):
    low = 0
    high = len(cards)-1
    
    while low <= high:
        mid = (low + high) // 2
        result = test_location(cards, query, mid)
        
        print("Low:", low, "High:", high)
        if result == 'found':
            return mid
        elif result == 'left':
            high = mid - 1
        elif result == 'right':
            low = mid + 1
    return -1

# %%
evaluate_test_case(locate_card, tests[9])
# Out:
# Input:
# {'cards': [7, 7, 7, 7, 3, 3, 3, 3, 3, 2, 2, 2, 1, 1], 'query': 3}
#
# Expected Output:
# 4
#
# mid: 6 , mid_number: 3
# Low: 0 High: 13
# mid: 2 , mid_number: 7
# Low: 0 High: 5
# mid: 4 , mid_number: 3
# Low: 3 High: 5
#
# Actual Output:
# 4
#
# Execution Time:
# 0.106 ms
#
# Test Result:
# PASSED
# (4, True, 0.106)

# %%
evaluate_test_cases(locate_card, tests)
# Out:
# TEST CASE #0
# mid: 3 , mid_number: 7
# Low: 0 High: 7
#
# Input:
# {'cards': [13, 11, 10, 7, 4, 3, 1, 0], 'query': 7}
#
# Expected Output:
# 3
#
#
# Actual Output:
# 3
#
# Execution Time:
# 0.14 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #1
# mid: 3 , mid_number: 7
# Low: 0 High: 7
# mid: 5 , mid_number: 3
# Low: 4 High: 7
# mid: 6 , mid_number: 1
# Low: 6 High: 7
#
# Input:
# {'cards': [13, 11, 10, 7, 4, 3, 1, 0], 'query': 1}
#
# Expected Output:
# 6
#
#
# Actual Output:
# 6
#
# Execution Time:
# 0.323 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #2
# mid: 3 , mid_number: 7
# Low: 0 High: 7
#
# Input:
# {'cards': [13, 11, 10, 7, 4, 3, 1, 0], 'query': 7}
#
# Expected Output:
# 3
#
#
# Actual Output:
# 3
#
# Execution Time:
# 0.112 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #3
# mid: 1 , mid_number: -1
# Low: 0 High: 3
# mid: 2 , mid_number: -9
# Low: 2 High: 3
# mid: 3 , mid_number: -127
# Low: 3 High: 3
#
# Input:
# {'cards': [3, -1, -9, -127], 'query': -127}
#
# ...

# %% [markdown]
# # Generic Binary Search

# %%
def binary_search(lo, hi, condition):
    while lo <= hi:
        mid = (lo + hi)// 2
        result = condition(mid)
        if result == 'found':
            return mid
        elif result == 'left':
            hi = mid - 1
        else:
            lo = mid + 1
    return -1

# %% [markdown]
# ### Function closure
# Function inside a function

# %%
def locate_card(cards, query):
    
    def condition(mid):
        if cards[mid] == query:
            if mid > 0 and cards[mid-1] == query:
                return 'left'
            else: 
                return 'found'
        elif cards[mid] < query:
            return 'left'
        else:
            return 'right'
        
    return binary_search(0, len(cards)-1, condition)

# %%
evaluate_test_cases(locate_card, tests)
# Out:
# TEST CASE #0
#
# Input:
# {'cards': [13, 11, 10, 7, 4, 3, 1, 0], 'query': 7}
#
# Expected Output:
# 3
#
#
# Actual Output:
# 3
#
# Execution Time:
# 0.02 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #1
#
# Input:
# {'cards': [13, 11, 10, 7, 4, 3, 1, 0], 'query': 1}
#
# Expected Output:
# 6
#
#
# Actual Output:
# 6
#
# Execution Time:
# 0.01 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #2
#
# Input:
# {'cards': [13, 11, 10, 7, 4, 3, 1, 0], 'query': 7}
#
# Expected Output:
# 3
#
#
# Actual Output:
# 3
#
# Execution Time:
# 0.006 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #3
#
# Input:
# {'cards': [3, -1, -9, -127], 'query': -127}
#
# Expected Output:
# 3
#
#
# Actual Output:
# 3
#
# Execution Time:
# 0.008 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #4
#
# Input:
# {'cards': [3, -1, -9, -127], 'query': 3}
#
# Expected Output:
# 0
#
#
# Actual Output:
# 0
#
# Execution Time:
# 0.006 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #5
#
# Input:
# {'cards': [6], 'query': 6}
#
# ...

# %% [markdown]
# # Question
# Given an array of integers nums sorted in ascending order, find the starting and ending position of a given number.

# %%
def first_position(num, target):
    def condition(mid):
        if num[mid] == target:
            if mid > 0 and nums[mid - 1] == target:
                return 'left'
            return 'found'
        elif nums[mid] < target:
            return 'right'
        else: 
            return 'left'
        
    return binary_search(0, len(nums)-1, condition)

def last_position(nums, target):
    def condition(mid):
        if nums[mid] == target:
            if mid < len(nums)-1 and nums[mid+1] == target:
                return 'right'
            return 'found'
        elif nums[mid] < target:
            return 'right'
        else:
            return 'left'
    return binary_search(0, len(nums)-1, condition)

def first_and_last_position(nums, target):
    return first_position(nums, target), last_position(nums, target)
